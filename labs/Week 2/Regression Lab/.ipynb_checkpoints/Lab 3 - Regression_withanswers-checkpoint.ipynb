# %% [markdown]
# # Introduction to Linear Regression

# %% [markdown]
# Regression is the process of learning a mapping from a vector of input data to a quantitative output given a set of observations. For example, coordinates in a room to Wi-Fi signal strength, someone's Body Mass Index to their life expectancy or a stock's performance over the last 5 days to it's value tomorrow.
#
# There are numerous methods for addressing this problem, each with their own set of assumptions and behaviour. Some are ideal for tackling large volumes of data while others provide more informative probabilistic outputs.
#
# In this lab, we'll focus on Linear Regression; a good point of reference for many other regression techniques and still used widely around the world today due to their simplicity and favourable scaling characteristics.

# %% [markdown]
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", index_col=0)

# %%
# Summarise the data
house_data.describe()
# Out:
#               Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count  2.190000e+02  70.000000  219.000000     219.000000   219.000000
# mean   4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std    4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min    2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%    3.190000e+05   2.000000    3.940000       8.000000     3.150000
# 50%    3.900000e+05   2.000000    4.930000       9.000000     3.400000
# 75%    5.125000e+05   3.000000    5.580000      10.000000     3.685000
# max    3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#               Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count  219.000000   219.000000     219.000000   219.000000    2.190000e+02
# mean    29.424658   873.200913     699.977169    49.197717    4.862191e+05
# std     49.155880  1392.893683    1175.278922    18.554525    3.978582e+05
# min      0.000000     0.000000       0.000000    16.700000    2.883650e+04
# 25%      0.000000     0.000000       0.000000    36.100000    3.074488e+05
# 50%      0.000000     0.000000       0.000000    50.000000    3.919800e+05
# 75%     41.000000  2614.000000    1344.000000    59.500000    5.324750e+05
# max    131.000000  7405.000000    6422.000000    93.900000    3.973508e+06

# %%
# Look for any linear correlations in the data
house_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.113943    0.118667      -0.034644    -0.072433
# Bath            0.113943  1.000000    0.163785       0.166330    -0.157517
# CrimeIndex      0.118667  0.163785    1.000000       0.194745     0.102382
# MinutesToLoop  -0.034644  0.166330    0.194745       1.000000     0.374829
# MilesToLake    -0.072433 -0.157517    0.102382       0.374829     1.000000
# Age             0.237720 -0.039220   -0.036644      -0.023820    -0.047087
# LotSizeSqft     0.443341 -0.029979   -0.008807      -0.053292     0.006240
# HouseSizeSqft   0.456272  0.698526    0.070952      -0.032437    -0.046517
# SchoolIndex    -0.072403 -0.047992   -0.100256      -0.196728    -0.205966
# EstimatedPrice  0.983784  0.105632    0.122793      -0.034185    -0.082604
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price           0.237720     0.443341       0.456272    -0.072403
# Bath           -0.039220    -0.029979       0.698526    -0.047992
# CrimeIndex     -0.036644    -0.008807       0.070952    -0.100256
# MinutesToLoop  -0.023820    -0.053292      -0.032437    -0.196728
# MilesToLake    -0.047087     0.006240      -0.046517    -0.205966
# Age             1.000000     0.716774       0.645147    -0.029953
# LotSizeSqft     0.716774     1.000000       0.828598    -0.055458
# HouseSizeSqft   0.645147     0.828598       1.000000    -0.023378
# SchoolIndex    -0.029953    -0.055458      -0.023378     1.000000
# EstimatedPrice  0.255628     0.454939       0.471783    -0.073825
#
#                 EstimatedPrice
# Price                 0.983784
# Bath                  0.105632
# CrimeIndex            0.122793
# MinutesToLoop        -0.034185
# MilesToLake          -0.082604
# Age                   0.255628
# LotSizeSqft           0.454939
# HouseSizeSqft         0.471783
# SchoolIndex          -0.073825
# EstimatedPrice        1.000000

# %%
# Plot the data
pd.scatter_matrix(house_data, figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114b5a110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1178e5d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117958390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1179d9810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117a5c690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117aca350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117c53610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117cb63d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e36850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117ce4410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x117f283d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117fad250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118010910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118092790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1180f77d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118179750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1181b0790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11826b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1182ef390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118451650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1184d84d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186401d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186aec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118735a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1187a3590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118824b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11887f6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a0db50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a919d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118aff6d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118b82550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118be7490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d69310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118dc5fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118e5f110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ed3f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f429d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118fc6850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11912b890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1191ab810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1191e6850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1192a15d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119424450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119488710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11950b590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119573290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1195fd390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119680210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1196ce710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119750e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1197c1290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119a44710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119a7c850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119b37290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119bb9110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119d20050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119d94e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119dfcb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119e86c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119f09b10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x119f79590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119ffb410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a864450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a8e43d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aa1d410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aad8190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ac4efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11acbf2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ad41150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ad9ee10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11ae27f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aeaad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11af1a810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11af9c690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119588fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b963d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b9eaa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ba61190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bae36d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb4a450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bbcc3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb63a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bcbd450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bf422d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bfa68d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c028750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c08e790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c212710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c248750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c3014d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c387350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c3ea610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c46e490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c4d6190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c55f290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c5e4110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c745b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c7c89d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c82ba10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8af990>]], dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
# - What looks to be affecting house prices from our initial inspection?
# - What is the type of relationship in those variables affecting price?

# %%
# create a fitted model in one line
lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 -28995.66*3 + 133*350
# Out:
# 467873.02

# %%
# Create a pandas DataFrame from this data.

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):              0.269
# Time:                        18:16:47   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016      9.89e+04  9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803     -2.61e+05  2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187       -66.297   332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Let's try just the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):          6.25e-164
# Time:                        18:16:47   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758     -1.28e+04  1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000         0.965     1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([   30901.56354902,  3933717.48261279])

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# then, plot the least squares line
plt.plot(X_new, preds, c='red', linewidth=2)

# %%
# Try selecting different variables or combinations of variables. Can you get a better fit?

# %% [markdown]
# ## Themepark

# %% [markdown]
# The file themepark.csv has some data from a theme park. Children were asked to rate their experience on a scale
# from 0-5. This data was compared against the number of hours they spent in the park.

# %%
# Create a pandas DataFrame from this data.
theme = pd.read_csv("themepark.csv")
theme.head(5)
# Out:
#    Hours  Enjoyment
# 0      1          1
# 1      2          3
# 2      3          4
# 3      4          5
# 4      5          5

# %%
# Have a look at the data (e.g. display the head or tail, use describe, etc.)
theme.describe()
# Out:
#            Hours  Enjoyment
# count  27.000000  27.000000
# mean    2.740741   3.148148
# std     1.456883   1.610153
# min     1.000000   0.000000
# 25%     1.500000   2.000000
# 50%     3.000000   3.000000
# 75%     4.000000   4.500000
# max     5.000000   5.000000

# %%
# Draw a scatterplot of this data.
theme.plot(kind="scatter",x='Hours',y='Enjoyment')

# %%
# Try doing a linear regression on this data
# create a fitted model in one line
lm = smf.ols(formula='Enjoyment ~ Hours', data=theme).fit()

# print the coefficients
lm.params
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Enjoyment   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.660
# Method:                 Least Squares   F-statistic:                     51.47
# Date:                Wed, 19 Oct 2016   Prob (F-statistic):           1.61e-07
# Time:                        18:49:55   Log-Likelihood:                -35.570
# No. Observations:                  27   AIC:                             75.14
# Df Residuals:                      25   BIC:                             77.73
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.6631      0.391      1.697      0.102        -0.142     1.468
# Hours          0.9067      0.126      7.174      0.000         0.646     1.167
# ==============================================================================
# Omnibus:                        0.596   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.742   Jarque-Bera (JB):                0.660
# Skew:                           0.138   Prob(JB):                        0.719
# Kurtosis:                       2.285   Cond. No.                         7.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Plot this regression over the top of the data. Could the regression be better?
X_new = pd.DataFrame({'Hours': [theme.Hours.min(), theme.Hours.max()]})
X_new.head()

preds = lm.predict(X_new)
#preds

# first, plot the observed data
theme.plot(kind='scatter', x='Hours', y='Enjoyment')

# then, plot the least squares line
plt.plot(X_new, preds, c='red', linewidth=2)
